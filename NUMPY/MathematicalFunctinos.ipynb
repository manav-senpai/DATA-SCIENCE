# %%
import numpy as np

# %%
 arr = np.array([2,3,4,5,6,7])

# %%
arr
# Out:
# array([2, 3, 4, 5, 6, 7])

# %%
np.mean(arr)
# Out:
# 4.5

# %%
np.max(arr)
# Out:
# 7

# %%
np.std(arr)
# Out:
# 1.707825127659933

# %%
np.var(arr)
# Out:
# 2.9166666666666665

# %%
np.sum(arr)
# Out:
# 27

# %%
np.unique(arr)
# Out:
# array([2, 3, 4, 5, 6, 7])
