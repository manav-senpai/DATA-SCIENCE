# %%
import numpy as np

# %%
arr = np.array([23,34,5,34])

# %%
arr.dtype
# Out:
# dtype('int32')

# %%
arr.astype("float64")
# Out:
# array([23., 34.,  5., 34.])

# %%
arr2 = np.array([23,435,45,76,34], dtype="float64")

# %%
arr2
# Out:
# array([ 23., 435.,  45.,  76.,  34.])

# %%
arr2.nbytes
# Out:
# 40
