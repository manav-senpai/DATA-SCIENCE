# %%
import numpy as np

array1 = np.array([23,34,456,23,54,65,32,454,56,76,654,32,43,657,7,54,34,54,6,67,43])

# %%
array1
# Out:
# array([ 23,  34, 456,  23,  54,  65,  32, 454,  56,  76, 654,  32,  43,
#        657,   7,  54,  34,  54,   6,  67,  43])

# %%
arr2 = np.array([1.1, 2.2, 3.3])

# %%
arr3 = arr2.astype(int)

# %%
arr3
# Out:
# array([1, 2, 3])

# %%
arr4 = np.array([2,3,4,5,6,7,8,9,0])

# %%
arr5 = np.array([])
if (arr4.any() % 2 ==0):
    arr5 = arr5.append(arr4)

# %%
arr5
# Out:
# array([], dtype=float64)
