# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#             Actor                         Film  Year              Genre  \
# 0      Ram Charan                          RRR  2022       Action/Drama
# 1      Allu Arjun             Pushpa: The Rise  2021       Action/Crime
# 2  Shah Rukh Khan                        Jawan  2023    Action/Thriller
# 3         Prabhas  Baahubali 2: The Conclusion  2017     Action/Fantasy
# 4      Aamir Khan                       Dangal  2016        Drama/Sport
# 5     Rajinikanth                            2  2018      Sci-Fi/Action
# 6            Yash             K.G.F: Chapter 2  2022       Action/Crime
# 7   Ranbir Kapoor                   Brahm?stra  2022  Fantasy/Adventure
# 8  Hrithik Roshan                          War  2019    Action/Thriller
# 9           Vijay                          Leo  2023    Action/Thriller
#
#   Box Office Income (USD)  IMDb Rating
# 0             160,000,000          8.0
# 1             130,000,000          7.6
# 2             137,000,000          7.0
# ...

# %%
df.sort_values("Year",ascending=False)
# Out:
#             Actor                         Film  Year              Genre  \
# 2  Shah Rukh Khan                        Jawan  2023    Action/Thriller
# 9           Vijay                          Leo  2023    Action/Thriller
# 0      Ram Charan                          RRR  2022       Action/Drama
# 6            Yash             K.G.F: Chapter 2  2022       Action/Crime
# 7   Ranbir Kapoor                   Brahm?stra  2022  Fantasy/Adventure
# 1      Allu Arjun             Pushpa: The Rise  2021       Action/Crime
# 8  Hrithik Roshan                          War  2019    Action/Thriller
# 5     Rajinikanth                            2  2018      Sci-Fi/Action
# 3         Prabhas  Baahubali 2: The Conclusion  2017     Action/Fantasy
# 4      Aamir Khan                       Dangal  2016        Drama/Sport
#
#   Box Office Income (USD)  IMDb Rating
# 2             137,000,000          7.0
# 9             100,000,000          7.2
# 0             160,000,000          8.0
# ...

# %%
df.sort_values(["Year","IMDb Rating"])
# Out:
#             Actor                         Film  Year              Genre  \
# 4      Aamir Khan                       Dangal  2016        Drama/Sport
# 3         Prabhas  Baahubali 2: The Conclusion  2017     Action/Fantasy
# 5     Rajinikanth                            2  2018      Sci-Fi/Action
# 8  Hrithik Roshan                          War  2019    Action/Thriller
# 1      Allu Arjun             Pushpa: The Rise  2021       Action/Crime
# 7   Ranbir Kapoor                   Brahm?stra  2022  Fantasy/Adventure
# 0      Ram Charan                          RRR  2022       Action/Drama
# 6            Yash             K.G.F: Chapter 2  2022       Action/Crime
# 2  Shah Rukh Khan                        Jawan  2023    Action/Thriller
# 9           Vijay                          Leo  2023    Action/Thriller
#
#   Box Office Income (USD)  IMDb Rating
# 4             300,000,000          8.3
# 3             278,000,000          8.2
# 5             110,000,000          6.2
# ...

# %%
df2 = df.sort_values(["Year","IMDb Rating"]).copy()

# %%
df2.index
# Out:
# Index([4, 3, 5, 8, 1, 7, 0, 6, 2, 9], dtype='int64')

# %%
df2.reset_index(drop=True)
# Out:
#             Actor                         Film  Year              Genre  \
# 0      Aamir Khan                       Dangal  2016        Drama/Sport
# 1         Prabhas  Baahubali 2: The Conclusion  2017     Action/Fantasy
# 2     Rajinikanth                            2  2018      Sci-Fi/Action
# 3  Hrithik Roshan                          War  2019    Action/Thriller
# 4      Allu Arjun             Pushpa: The Rise  2021       Action/Crime
# 5   Ranbir Kapoor                   Brahm?stra  2022  Fantasy/Adventure
# 6      Ram Charan                          RRR  2022       Action/Drama
# 7            Yash             K.G.F: Chapter 2  2022       Action/Crime
# 8  Shah Rukh Khan                        Jawan  2023    Action/Thriller
# 9           Vijay                          Leo  2023    Action/Thriller
#
#   Box Office Income (USD)  IMDb Rating
# 0             300,000,000          8.3
# 1             278,000,000          8.2
# 2             110,000,000          6.2
# ...

# %%
df2
# Out:
#             Actor                         Film  Year              Genre  \
# 4      Aamir Khan                       Dangal  2016        Drama/Sport
# 3         Prabhas  Baahubali 2: The Conclusion  2017     Action/Fantasy
# 5     Rajinikanth                            2  2018      Sci-Fi/Action
# 8  Hrithik Roshan                          War  2019    Action/Thriller
# 1      Allu Arjun             Pushpa: The Rise  2021       Action/Crime
# 7   Ranbir Kapoor                   Brahm?stra  2022  Fantasy/Adventure
# 0      Ram Charan                          RRR  2022       Action/Drama
# 6            Yash             K.G.F: Chapter 2  2022       Action/Crime
# 2  Shah Rukh Khan                        Jawan  2023    Action/Thriller
# 9           Vijay                          Leo  2023    Action/Thriller
#
#   Box Office Income (USD)  IMDb Rating
# 4             300,000,000          8.3
# 3             278,000,000          8.2
# 5             110,000,000          6.2
# ...

# %%
    df2
# Out:
#             Actor                         Film  Year              Genre  \
# 4      Aamir Khan                       Dangal  2016        Drama/Sport
# 3         Prabhas  Baahubali 2: The Conclusion  2017     Action/Fantasy
# 5     Rajinikanth                            2  2018      Sci-Fi/Action
# 8  Hrithik Roshan                          War  2019    Action/Thriller
# 1      Allu Arjun             Pushpa: The Rise  2021       Action/Crime
# 7   Ranbir Kapoor                   Brahm?stra  2022  Fantasy/Adventure
# 0      Ram Charan                          RRR  2022       Action/Drama
# 6            Yash             K.G.F: Chapter 2  2022       Action/Crime
# 2  Shah Rukh Khan                        Jawan  2023    Action/Thriller
# 9           Vijay                          Leo  2023    Action/Thriller
#
#   Box Office Income (USD)  IMDb Rating
# 4             300,000,000          8.3
# 3             278,000,000          8.2
# 5             110,000,000          6.2
# ...

# %%
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#             Actor                         Film  Year              Genre  \
# 0      Aamir Khan                       Dangal  2016        Drama/Sport
# 1         Prabhas  Baahubali 2: The Conclusion  2017     Action/Fantasy
# 2     Rajinikanth                            2  2018      Sci-Fi/Action
# 3  Hrithik Roshan                          War  2019    Action/Thriller
# 4      Allu Arjun             Pushpa: The Rise  2021       Action/Crime
# 5   Ranbir Kapoor                   Brahm?stra  2022  Fantasy/Adventure
# 6      Ram Charan                          RRR  2022       Action/Drama
# 7            Yash             K.G.F: Chapter 2  2022       Action/Crime
# 8  Shah Rukh Khan                        Jawan  2023    Action/Thriller
# 9           Vijay                          Leo  2023    Action/Thriller
#
#   Box Office Income (USD)  IMDb Rating
# 0             300,000,000          8.3
# 1             278,000,000          8.2
# 2             110,000,000          6.2
# ...

# %%
df2.sort_index()
# Out:
#             Actor                         Film  Year              Genre  \
# 0      Aamir Khan                       Dangal  2016        Drama/Sport
# 1         Prabhas  Baahubali 2: The Conclusion  2017     Action/Fantasy
# 2     Rajinikanth                            2  2018      Sci-Fi/Action
# 3  Hrithik Roshan                          War  2019    Action/Thriller
# 4      Allu Arjun             Pushpa: The Rise  2021       Action/Crime
# 5   Ranbir Kapoor                   Brahm?stra  2022  Fantasy/Adventure
# 6      Ram Charan                          RRR  2022       Action/Drama
# 7            Yash             K.G.F: Chapter 2  2022       Action/Crime
# 8  Shah Rukh Khan                        Jawan  2023    Action/Thriller
# 9           Vijay                          Leo  2023    Action/Thriller
#
#   Box Office Income (USD)  IMDb Rating
# 0             300,000,000          8.3
# 1             278,000,000          8.2
# 2             110,000,000          6.2
# ...

# %%
df2["Rank"] = df2["IMDb Rating"].rank(ascending=False, method="dense")

# %%
df2
# Out:
#             Actor                         Film  Year              Genre  \
# 0      Aamir Khan                       Dangal  2016        Drama/Sport
# 1         Prabhas  Baahubali 2: The Conclusion  2017     Action/Fantasy
# 2     Rajinikanth                            2  2018      Sci-Fi/Action
# 3  Hrithik Roshan                          War  2019    Action/Thriller
# 4      Allu Arjun             Pushpa: The Rise  2021       Action/Crime
# 5   Ranbir Kapoor                   Brahm?stra  2022  Fantasy/Adventure
# 6      Ram Charan                          RRR  2022       Action/Drama
# 7            Yash             K.G.F: Chapter 2  2022       Action/Crime
# 8  Shah Rukh Khan                        Jawan  2023    Action/Thriller
# 9           Vijay                          Leo  2023    Action/Thriller
#
#   Box Office Income (USD)  IMDb Rating  Rank
# 0             300,000,000          8.3   1.5
# 1             278,000,000          8.2   3.0
# ...

# %%
df2.rename(columns={"Actor":"Naam"}, inplace=True)

# %%
df2
# Out:
#              Naam                         Film  Year              Genre  \
# 0      Aamir Khan                       Dangal  2016        Drama/Sport
# 1         Prabhas  Baahubali 2: The Conclusion  2017     Action/Fantasy
# 2     Rajinikanth                            2  2018      Sci-Fi/Action
# 3  Hrithik Roshan                          War  2019    Action/Thriller
# 4      Allu Arjun             Pushpa: The Rise  2021       Action/Crime
# 5   Ranbir Kapoor                   Brahm?stra  2022  Fantasy/Adventure
# 6      Ram Charan                          RRR  2022       Action/Drama
# 7            Yash             K.G.F: Chapter 2  2022       Action/Crime
# 8  Shah Rukh Khan                        Jawan  2023    Action/Thriller
# 9           Vijay                          Leo  2023    Action/Thriller
#
#   Box Office Income (USD)  IMDb Rating  Rank
# 0             300,000,000          8.3   1.0
# 1             278,000,000          8.2   2.0
# ...

# %%
df2 = df2[["Film","Actor","Year","Genre","Imdb Rating","Box Office Income (USD)	"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df2 = df2[["Film","Actor","Year","Genre","Imdb Rating","Box Office Income (USD)	"]]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
# ...

# %%
df2
# Out:
#              Naam                         Film  Year              Genre  \
# 0      Aamir Khan                       Dangal  2016        Drama/Sport
# 1         Prabhas  Baahubali 2: The Conclusion  2017     Action/Fantasy
# 2     Rajinikanth                            2  2018      Sci-Fi/Action
# 3  Hrithik Roshan                          War  2019    Action/Thriller
# 4      Allu Arjun             Pushpa: The Rise  2021       Action/Crime
# 5   Ranbir Kapoor                   Brahm?stra  2022  Fantasy/Adventure
# 6      Ram Charan                          RRR  2022       Action/Drama
# 7            Yash             K.G.F: Chapter 2  2022       Action/Crime
# 8  Shah Rukh Khan                        Jawan  2023    Action/Thriller
# 9           Vijay                          Leo  2023    Action/Thriller
#
#   Box Office Income (USD)  IMDb Rating  Rank
# 0             300,000,000          8.3   1.0
# 1             278,000,000          8.2   2.0
# ...
