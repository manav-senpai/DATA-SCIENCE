# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#             Actor                         Film  Year              Genre  \
# 0      Ram Charan                          RRR  2022       Action/Drama
# 1      Allu Arjun             Pushpa: The Rise  2021       Action/Crime
# 2  Shah Rukh Khan                        Jawan  2023    Action/Thriller
# 3         Prabhas  Baahubali 2: The Conclusion  2017     Action/Fantasy
# 4      Aamir Khan                       Dangal  2016        Drama/Sport
# 5     Rajinikanth                            2  2018      Sci-Fi/Action
# 6            Yash             K.G.F: Chapter 2  2022       Action/Crime
# 7   Ranbir Kapoor                   Brahm?stra  2022  Fantasy/Adventure
# 8  Hrithik Roshan                          War  2019    Action/Thriller
# 9           Vijay                          Leo  2023    Action/Thriller
#
#   Box Office Income (USD)  IMDb Rating
# 0             160,000,000          8.0
# 1             130,000,000          7.6
# 2             137,000,000          7.0
# ...

# %%
df['Actor']
# Out:
# 0        Ram Charan
# 1        Allu Arjun
# 2    Shah Rukh Khan
# 3           Prabhas
# 4        Aamir Khan
# 5       Rajinikanth
# 6              Yash
# 7     Ranbir Kapoor
# 8    Hrithik Roshan
# 9             Vijay
# Name: Actor, dtype: object

# %%
df[['Actor','IMDb Rating']]
# Out:
#             Actor  IMDb Rating
# 0      Ram Charan          8.0
# 1      Allu Arjun          7.6
# 2  Shah Rukh Khan          7.0
# 3         Prabhas          8.2
# 4      Aamir Khan          8.3
# 5     Rajinikanth          6.2
# 6            Yash          8.3
# 7   Ranbir Kapoor          5.6
# 8  Hrithik Roshan          6.5
# 9           Vijay          7.2

# %%
df.loc[1]
# Out:
# Actor                            Allu Arjun
# Film                       Pushpa: The Rise
# Year                                   2021
# Genre                          Action/Crime
# Box Office Income (USD)         130,000,000
# IMDb Rating                             7.6
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# Actor                            Allu Arjun
# Film                       Pushpa: The Rise
# Year                                   2021
# Genre                          Action/Crime
# Box Office Income (USD)         130,000,000
# IMDb Rating                             7.6
# Name: 1, dtype: object

# %%
df.loc[8,'IMDb Rating']
# Out:
# 6.5

# %%
df.iloc[7,5]
# Out:
# 5.6

# %%
df.loc[0:2,["Actor", "IMDb Rating"]]
# Out:
#             Actor  IMDb Rating
# 0      Ram Charan          8.0
# 1      Allu Arjun          7.6
# 2  Shah Rukh Khan          7.0

# %%
df.iloc[0:2, 0:2]
# Out:
#         Actor              Film
# 0  Ram Charan               RRR
# 1  Allu Arjun  Pushpa: The Rise

# %%
df.at[0,"Actor"]
# Out:
# 'Ram Charan'

# %%
df.iat[0,0]
# Out:
# 'Ram Charan'

# %%
df[df["IMDb Rating"]>8]["Actor"]
# Out:
# 3       Prabhas
# 4    Aamir Khan
# 6          Yash
# Name: Actor, dtype: object

# %%
df[(df["IMDb Rating"]>6) & (df["Year"]>2018)]
# Out:
#             Actor              Film  Year            Genre  \
# 0      Ram Charan               RRR  2022     Action/Drama
# 1      Allu Arjun  Pushpa: The Rise  2021     Action/Crime
# 2  Shah Rukh Khan             Jawan  2023  Action/Thriller
# 6            Yash  K.G.F: Chapter 2  2022     Action/Crime
# 8  Hrithik Roshan               War  2019  Action/Thriller
# 9           Vijay               Leo  2023  Action/Thriller
#
#   Box Office Income (USD)  IMDb Rating
# 0             160,000,000          8.0
# 1             130,000,000          7.6
# 2             137,000,000          7.0
# 6             160,000,000          8.3
# 8              76,000,000          6.5
# 9             100,000,000          7.2

# %%
df.query("Year > 2019")
# Out:
#             Actor              Film  Year              Genre  \
# 0      Ram Charan               RRR  2022       Action/Drama
# 1      Allu Arjun  Pushpa: The Rise  2021       Action/Crime
# 2  Shah Rukh Khan             Jawan  2023    Action/Thriller
# 6            Yash  K.G.F: Chapter 2  2022       Action/Crime
# 7   Ranbir Kapoor        Brahm?stra  2022  Fantasy/Adventure
# 9           Vijay               Leo  2023    Action/Thriller
#
#   Box Office Income (USD)  IMDb Rating
# 0             160,000,000          8.0
# 1             130,000,000          7.6
# 2             137,000,000          7.0
# 6             160,000,000          8.3
# 7             120,000,000          5.6
# 9             100,000,000          7.2

# %%
df2 = df[['Actor', 'IMDb Rating']] = "Mundane"

# %%
df2
# Out:
# 'Mundane'

# %%
df
# Out:
#      Actor                         Film  Year              Genre  \
# 0  Mundane                          RRR  2022       Action/Drama
# 1  Mundane             Pushpa: The Rise  2021       Action/Crime
# 2  Mundane                        Jawan  2023    Action/Thriller
# 3  Mundane  Baahubali 2: The Conclusion  2017     Action/Fantasy
# 4  Mundane                       Dangal  2016        Drama/Sport
# 5  Mundane                            2  2018      Sci-Fi/Action
# 6  Mundane             K.G.F: Chapter 2  2022       Action/Crime
# 7  Mundane                   Brahm?stra  2022  Fantasy/Adventure
# 8  Mundane                          War  2019    Action/Thriller
# 9  Mundane                          Leo  2023    Action/Thriller
#
#   Box Office Income (USD) IMDb Rating
# 0             160,000,000     Mundane
# 1             130,000,000     Mundane
# 2             137,000,000     Mundane
# 3             278,000,000     Mundane
# 4             300,000,000     Mundane
# ...
